#    1.11111111   1.31313131   1.51515152   1.71717172   1.91919192
#    2.12121212   2.32323232   2.52525253   2.72727273   2.92929293
#    3.13131313   3.33333333   3.53535354   3.73737374   3.93939394
#    4.14141414   4.34343434   4.54545455   4.74747475   4.94949495
#    5.15151515   5.35353535   5.55555556   5.75757576   5.95959596
#    6.16161616   6.36363636   6.56565657   6.76767677   6.96969697
#    7.17171717   7.37373737   7.57575758   7.77777778   7.97979798
#    8.18181818   8.38383838   8.58585859   8.78787879   8.98989899
#    9.19191919   9.39393939   9.5959596    9.7979798   10.        ]

# %%
x = np.linspace(-6,6,10)

# %%
y = 5*x + 1
y
# Out:
# array([-29.        , -22.33333333, -15.66666667,  -9.        ,
#         -2.33333333,   4.33333333,  11.        ,  17.66666667,
#         24.33333333,  31.        ])

# %%
plt.scatter(x, y, marker='o');

# %%
ww0, ww1 = np.meshgrid(w0, w1)

#print(Y)
ww1
# Out:
# array([[-10.       , -10.       , -10.       , ..., -10.       ,
#         -10.       , -10.       ],
#        [ -9.7979798,  -9.7979798,  -9.7979798, ...,  -9.7979798,
#          -9.7979798,  -9.7979798],
#        [ -9.5959596,  -9.5959596,  -9.5959596, ...,  -9.5959596,
#          -9.5959596,  -9.5959596],
#        ...,
#        [  9.5959596,   9.5959596,   9.5959596, ...,   9.5959596,
#           9.5959596,   9.5959596],
#        [  9.7979798,   9.7979798,   9.7979798, ...,   9.7979798,
#           9.7979798,   9.7979798],
#        [ 10.       ,  10.       ,  10.       , ...,  10.       ,
#          10.       ,  10.       ]])

# %%
def f(ww0,ww1,x,y,m):
    e = 0
    for i in range(m):
        e += ((ww0+ww1*x[i]) - y[i] )**2
    return e

# %%
Z = f(ww0,ww1,x,y,m=len(x))
print(Z)
# Out:
# [[34210.         34165.96367718 34122.74359759 ... 33738.90521375
#   33774.04448526 33810.        ]
#  [33327.09689487 33283.06057205 33239.84049247 ... 32856.00210863
#   32891.14138013 32927.09689487]
#  [32456.16535728 32412.12903445 32368.90895487 ... 31985.07057103
#   32020.20984253 32056.16535728]
#  ...
#  [ 4308.01720913  4263.9808863   4220.76080672 ...  3836.92242288
#    3872.06169438  3908.01720913]
#  [ 4586.35615413  4542.31983131  4499.09975173 ...  4115.26136789
#    4150.40063939  4186.35615413]
#  [ 4876.66666667  4832.63034384  4789.41026426 ...  4405.57188042
#    4440.71115192  4476.66666667]]

# %%
fig = plt.figure()
#ax = plt.axes(projection='3d')
plt.contour(ww0, ww1, Z, levels = [i for i in np.arange(0,1000,40)])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(ww0, ww1, Z, cmap='viridis', rstride=1, cstride=1, edgecolor='none')
